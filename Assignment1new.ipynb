# %% [markdown]
# Q1. Write a program that takes two numbers (a = 15 , b = 4) and prints their:
# - Sum
#
# - Difference
#
# - Product
#
# - Division
#
# - Floor Division
#
# - Modulus

# %%
a=15
b=4
print("sum",a+b)
print("difference",a-b)
print("product",a*b)
print("floor division",a//b)
print("Modulus",a%b)
# Out:
# sum 19
# difference 11
# product 60
# floor division 3
# Modulus 3

# %% [markdown]
# Q2. Write a code to store your favorite food in a variable and print it.

# %%
fav_fruit="Mango","Apple","Banana","Pomegranate"
print(fav_fruit)
# Out:
# ('Mango', 'Apple', 'Banana', 'Pomegranate')

# %% [markdown]
# Q3. "I have 22 apples and 33 mangoes. How many fruits do I have in total?"
#
# apple = '22'
#
# mangoes = 33

# %%
apple='22'
mangoes=33
total=int(apple)+mangoes
print("The total fruits I have is",total)
# Out:
# The total fruits I have is 55

# %% [markdown]
# Q4. Check the type and convert:
# (num1 = 10, num2 = 5.6, num3 = 4.43, num4='23')
#
# - Integer to float
#
# - Float to integer
#
# - Float to String
#
# - String to Integer

# %%
num1=10
num2=5.6
num3=4.43
num4='23'
print(type(num1))
print(float(num1))
print(type(num2))
print(int(num2))
print(type(num3))
print(str(num3))
print(type(num4))
print(int(num4))
# Out:
# <class 'int'>
# 10.0
# <class 'float'>
# 5
# <class 'float'>
# 4.43
# <class 'str'>
# 23

# %% [markdown]
# Q5. Store in a varibale: Write Your name , Your age, Add 1 to your age using a variable, Print final age

# %%
name="Saad Ullah Malik"
age=23
new_age=age+1
print(new_age)
# Out:
# 24

# %% [markdown]
# Q6.
#
# a = 2
#
# b = 1
#
# c = 6
#
# d = 3
#
# - Add a and b
#
# - Subtract c and a
#
# - Multiply d and b
#
# - Divide c and d (float division)
#
# - Find modulus of c divided by d
#
# - Square of (d+a)

# %%
a=2
b=1
c=6
d=3
print("Addition of  a and b is",a+b)
print("Subtraction of c and a is",c-a)
print("Multiply d and b is",d*b)
print("Divide c and d is",c/d)
print("Modulus of c and d",c%d)
print("square of d+a is",(d+a)**2)
# Out:
# Addition of  a and b is 3
# Subtraction of c and a is 4
# Multiply d and b is 3
# Divide c and d is 2.0
# Modulus of c and d 0
# square of d+a is 25

# %% [markdown]
# Q7.
#
# You were 20 years old in the year 2020.
# Now add 5 more years to your age.
# What is your current age now?
#
# Store age in a variable called age. Print final output in same variable

# %%
age=20
age=20+5
print("Current age now is",age)
# Out:
# Current age now is 25

# %% [markdown]
# Q8.
#
# a = '2'
#
# b = '11'
#
# c = 6.3
#
# - Convert a to integer then add to c
#
# - Convert b to float then multiply by c
#
# - Convert c to integer then add to c

# %%
a='2'
b='11'
c=6.3
a=print(int(a)+c)
print(float(b)*c)
print(int(c)+c)
# Out:
# 8.3
# 69.3
# 12.3

# %% [markdown]
# Q9.
#
# You had 12 books, and you gave 4 to your friend.
# How many books do you have now?
#
# Store books in a variable called books. Print final output in same variable

# %%
books=12
books=books-4
print(books)
# Out:
# 8

# %% [markdown]
# Q10.
#
# You baked 5 cookies. You baked 3 times more cookies today.
# How many cookies did you bake today?
#
# Store cookies in a variable called cookies. Print final output in same variable

# %%
cookie=5
cookie=cookie+3
print("Cookie baked today is",cookie)
# Out:
# Cookie baked today is 8

# %% [markdown]
# Q11.
# Solve the following expression using PEDMAS:
#
# **20 - 4 × (3 + 2) + 18 ÷ 3**

# %%
print(20-4*(3+2)+18/3)
# Out:
# 6.0
